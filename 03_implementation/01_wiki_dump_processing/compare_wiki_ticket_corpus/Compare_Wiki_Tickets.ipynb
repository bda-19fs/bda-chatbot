# %% [markdown]
# # Compare the Wiki and the Ionesoft corpus

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Ionesoft ticket corpus
# These are the labeled tickets from ionesoft.

# %%
import pandas as pd

extract = './ionesoft_tickets_corrected_grammar.csv'
names=['ticket', 'type', 'client', 'issuer', 'inquiry', 'answer']

corpus = pd.read_csv(extract, sep=',', encoding='utf-8', names=names, skiprows=[0])
corpus['ticket'] = corpus['ticket'].astype(str)

corpus.head()
# Out:
#                ticket                        type client  issuer  \
# 0  2019030563000120.0           Fehler in der App   SVBA       3
# 1  2019030463000110.0           Fehler in der App   FOMA       3
# 2  2019022863000110.0     Anmeldung / Aktivierung   AGVS       3
# 3  2019022863000020.0  Geräteanzahl überschritten  BEOOK       3
# 4  2019022763000080.0  Geräteanzahl überschritten  BEOOK       3
#
#                                              inquiry  \
# 0  ich kann die bilder in übungen nicht bearbeite...
# 1  lückentexte weg daten verloren gegangen von pp...
# 2  bitte deaaktivieren sie dieses gerät. vielen d...
# 3  ich habe einen neuen laptop und möchte den alt...
# 4  offenbar habe ich die gerägeräteanzahl übersch...
#
#                         answer
# 0         Fehlerbericht senden
# 1         Fehlerbericht senden
# 2  Gerät entfernt, neu starten
# 3  Gerät entfernt, neu starten
# 4  Gerät entfernt, neu starten

# %% [markdown]
# Extract all words from the ticket texts.

# %%
for i in corpus[corpus['inquiry'].str.contains(r'\b' + 'apgemeldet' + r'\b', regex=True)]['inquiry']:
    print(i)

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("german")

def nlp_pipeline(text):
    text = text.replace('\\','')
    tokens = nltk.word_tokenize(text)
    
    words = []
    for word in tokens:
        stem = stemmer.stem(word)
        
        if any(char.isdigit() for char in stem):
            continue
        
        words.append(stem)
    return words

words_tickets = []
for text in corpus.inquiry:
    words_tickets.extend(nlp_pipeline(text))

len(words_tickets)
# Out:
# 32492

# %% [markdown]
# Then we extract the distinct words.

# %%
distinct_words = set(words_tickets)
len(distinct_words)
# Out:
# 2572

# %% [markdown]
# ## Wiki dump
# These are the distinct words from the wikipedia extract.

# %%
import json

wiki_words = json.load(open('word2index-tfidf-normalized.ind', 'rb'))

len(wiki_words)
# Out:
# 143605

# %% [markdown]
# ## Compare the Wiki and the ticket corpus
# Now we want to check how many words from the ticket corpus can be found in the wikipedia word list.

# %%
num_words = 0
missing_words = []

for word in distinct_words:
    if word in wiki_words:
        num_words = num_words + 1
    else:
        missing_words.append(word)

print(num_words)
# Out:
# 1905

# %%
len(missing_words)
# Out:
# 667

# %% [markdown]
# ## Now let's check the unclassified tickets
# Then we take a look at the tickets without labels.

# %%
unclassified = '../ionesoft_tickets/ionesoft_unclassified_texts.csv'

corpus_unclassified = pd.read_csv(unclassified, sep=',', encoding='ansi')
corpus_unclassified.head()
# Out:
#                                              inquiry
# 0  können sie mir bitte die homepage nennen auf d...
# 1  ich habe ein neues smartphone und wollte die t...
# 2  podcast lässt sich nicht abspielen. das wlan f...
# 3  obwohl ich eine lizenz über die schule habe ka...
# 4        aktivirungscode wird als ungültig gemeldet.

# %%
unclassified_words = []
for text in corpus_unclassified.inquiry:
    unclassified_words.extend(nlp_pipeline(text))

len(unclassified_words)
# Out:
# 19312

# %%
distinct_unclassified_words = set(unclassified_words)
len(distinct_unclassified_words)
# Out:
# 2372

# %%
num_words = 0
still_missing_words = []

for word in missing_words:
    if word in distinct_unclassified_words:
        num_words = num_words + 1
    else:
        still_missing_words.append(word)

print(num_words)
# Out:
# 144

# %% [markdown]
# There are still some missing words.

# %%
len(still_missing_words)
# Out:
# 523

# %%
still_missing_words[:5]
# Out:
# ['kontaaktdat', 'aaktivierungsschlussel', 'gewerbe', 'livia', 'desaktoprechn']

# %%
import pickle

pickle.dump(still_missing_words, open('missing_words_grammar.p', 'wb'))

# %%
still_missing_words
# Out:
# ['kontaaktdat',
#  'aaktivierungsschlussel',
#  'gewerbe',
#  'livia',
#  'desaktoprechn',
#  'flavia',
#  'gerateidentifikation',
#  'murt',
#  'zeistnungseditor',
#  'be-med',
#  'schaufelberg',
#  'modellehrgang',
#  'maksuti',
#  'android-gerat',
#  'kundg',
#  'textbaend',
#  'kontaaktaufnahm',
#  'ziimmermann',
#  'unvollstandi',
#  'runtergefahr',
#  'fehlermeldung',
#  'eleaktik-eleaktron',
#  'trosch',
#  'ruswil',
#  'akbxujuf',
#  'gedrucakt',
#  'eingegebenebn',
#  'iimm',
#  '-son',
#  'coudfunaktion',
#  'e-',
#  'pilotprojeakt',
#  'neulich',
#  'zh',
#  'sensoren+aaktor',
#  'spannungsabfall',
#  'passier',
#  'prufungsbuch',
#  'funaktion',
#  'testlizenzbuch',
#  'stv',
#  'aufschalten',
#  'franzosist',
#  'sps-praaktist',
#  'losungen/wort',
#  'nau',
#  'bearbeiten',
#  'gibgl',
#  'aaktivier',
#  'aufstart',
#  'beschranakt',
#  'far-los',
#  'phzh-account',
#  'funaktiontiert',
#  'markierfunaktion',
#  'ubeschritt',
#  'belehrt',
#  'reichmuth',
#  'hensel',
#  'bp',
#  'zuschnall',
#  'aufricht',
#  'ersatzgerat',
#  'logisterweis',
#  'rehweg',
#  'rauslosch',
#  'produakt',
#  'korrigieren',
#  'wuss',
#  'aaktualisierenierungscodewird',
#  'bestellnuimm',
#  'seinheit',
#  'heu',
#  'haklaj',
#  'porbl',
#  'anfrage',
#  'kaputteln',
#  'gutefall',
#  'ziimm',
#  'praaktist',
#  'luftungsanlag',
#  'moglicht',
#  'funaktioni',
#  'methigon',
#  'einlosen/',
#  'rechtklick',
#  'insallation/aaktualisiereniser',
#  'gerateuberschreit',
#  'cloud-funaktion',
#  'domanen-adminrecht',
#  'amag',
#  'aaktivi',
#  'funaktionieret',
#  'beziehungsweiseahlt',
#  'geschicakt',
#  'iimmernoch',
#  'dazwist',
#  'repetierentionsaufgab',
#  'gvpyegytnj',
#  'gelosch',
#  'installierent',
#  'werac',
#  'allenspach',
#  'aaktualisiereni',
#  'baltt',
#  'prol',
#  'losun',
#  'inzwist',
#  'konstruakteurin',
#  'fachrech',
#  'eingeschranakt',
#  'gradel',
#  '‚vitalzeich',
#  'sun.security.provider.certpath.suncertpathbuilderexception',
#  'flachdach',
#  'erstellen..ich',
#  'uberrschritt',
#  'qualcom',
#  'esthermartin',
#  'b.',
#  'brulhart',
#  'freundlichm',
#  'lizenznuimm',
#  'aufgehanakt',
#  'soimm',
#  'hep-elehrmittel',
#  'aaktiv',
#  'totalschad',
#  'gesellschafsbuch',
#  'rumschlag',
#  'grat',
#  'abgestutzt',
#  'celiku',
#  'aaktivierungscode',
#  'ubergangsmass',
#  'datein',
#  'abklar',
#  'autofizier',
#  'konstruakteur',
#  '//wwwohep-verlag.ch/elehrmittel-app-herunterlad',
#  'bets',
#  'texband',
#  'verantwortlich',
#  'zerndl',
#  'videographie',
#  'lm-a',
#  'deaaktiviert',
#  'gibl*',
#  'nuimm',
#  'berufsbildende',
#  'didgetom',
#  'remotedesaktop',
#  'aaktualisi',
#  'kaput',
#  'handlungsspezifischist',
#  'kaputtel',
#  'aaktuell',
#  'warschein',
#  'habe',
#  's.',
#  'aufgabe',
#  'trudi',
#  'motorbauart',
#  'qendresa',
#  'aspiration',
#  'pola',
#  'gragerateanzahl',
#  'konntet',
#  'baranowski',
#  'vertiefungsfrag',
#  'serricchio',
#  'berufsmaturitat',
#  'akaktivierungscod',
#  'untersturtz',
#  'franziska',
#  'schaffhaus',
#  'fehlurteil',
#  'inderbitzin',
#  'deaaktivi',
#  'hauschenrast',
#  '¦',
#  'backerin/konditorin',
#  'zuruckstell',
#  'mail-adressexxx',
#  'bzwo',
#  'funaktioniet',
#  'gin',
#  'jenige',
#  'zeichnungsvorlage',
#  'oaktob',
#  'entsprechen',
#  'wwwohep-verlag.ch',
#  'geratenzahl',
#  'englist',
#  'unterrichten',
#  'ihrkonntallecomputergerateloschenspieltkeinerolle.habekeinederangeeldetengeratemehr',
#  'male',
#  'anmeldung',
#  'lazar',
#  'zeitpunakt',
#  'herumzicakt',
#  'herunterhald',
#  'dobl',
#  'azfab',
#  'nando',
#  'de-',
#  'bemerakt',
#  'leuchtstift',
#  'oesch',
#  'entfurnen',
#  'ahang',
#  'uneingeschranakt',
#  'freistaltungscod',
#  'aaktuallisi',
#  '//',
#  'funaktionier',
#  'grundlage',
#  'uswo',
#  'repetierentionsfrag',
#  '*geragerateanzahl*',
#  '*steinmann',
#  'app-aaktualisierenier',
#  'freundlichn',
#  'bbb',
#  'schlegel',
#  'adelina',
#  'koonn',
#  'maschinenenelement',
#  'maibach',
#  'bkc',
#  'p.',
#  'funaktionstucht',
#  'zwistenzeit',
#  'ubershchritt',
#  'ruag',
#  '.geragerateanzahl',
#  'gelosst',
#  'leaktion',
#  'students-bwzofing',
#  'goetschi',
#  'aufgeg',
#  'reichen…',
#  'beook-team',
#  'uptat',
#  'stromweg',
#  'wwwoswissmem-elearning.ch',
#  'funaktionirt',
#  'kontaakti',
#  'aaktualisieren',
#  'aaktivierung/deaaktivier',
#  'ubernohm',
#  'inaaktiv',
#  'n.',
#  'pause',
#  'fvro',
#  'hoffend',
#  'hep-app',
#  'bucher-icon',
#  'ruedi',
#  '--',
#  'akoya',
#  'abmelden',
#  'freistallt',
#  'beziehungsweiseug',
#  'tbw-train',
#  '$',
#  'eith',
#  'bitte',
#  'eingellost',
#  'survac',
#  'anstreichen',
#  'steinmann',
#  'xxx.xxxxx',
#  'eleaktroniker/inn',
#  'aaktualisiereniert',
#  'desaktop',
#  'liestal',
#  'seite',
#  'drucakt',
#  'kss',
#  'gerate-anzahl',
#  'habeziehungsweiseuerstdieappaufmeinemiphoneaaktiviert.daichmirjetzteinipadgekaufthabemochteichdieappaufdiesemnutzen.dasiphonekanngeloschtwerd',
#  'byod',
#  'anschliessen',
#  'jetty',
#  'zugeschiakt',
#  'tafelmei',
#  'ubernihmt',
#  'zurucksezt',
#  'noemi',
#  'funaktiniert',
#  'fuaktion',
#  'eun',
#  'qv',
#  'verstantnis',
#  'swissmen-applikation',
#  'moch',
#  'desaktop-pc',
#  'benutzernamen.xxx',
#  'aaktualisierenier',
#  'aaktiviert',
#  'eingabe',
#  'gruse',
#  'instruaktor',
#  'gemerakt',
#  'aaktualisierenierungspfeil',
#  'vonnallenngerat',
#  'konditor',
#  'verschicakt',
#  'personalfuhr',
#  'maschineneworld',
#  'windlin',
#  'lenkgeometrist',
#  'verlinakt',
#  'gerateanzal',
#  'wiederbekomm',
#  'f.',
#  'furkan',
#  'fasl',
#  'aaktivierungscodecod',
#  'schuldireaktor',
#  'einstellungen',
#  'karriert',
#  'defeakt',
#  'lehrbetrieb',
#  'hanselmann',
#  '.konn',
#  'geratenazahl',
#  'wyss',
#  'anderun',
#  'alexandra',
#  'samtron',
#  'daten/markierungen/arbeitsblatt',
#  'konnnt',
#  'bucherzugriff',
#  'dêin',
#  'martinas',
#  'lizenz-limit',
#  'eventuellll',
#  'reihn',
#  'eingegebeneb',
#  'beook-buch',
#  'pensioni',
#  'leh',
#  'upda',
#  'kontaakt',
#  'buchenberg',
#  'saurenmann',
#  'elehrmittel-app',
#  'doinic',
#  'baustoffkunde',
#  'casadei',
#  'geupdat',
#  'trotzdemd',
#  'ineich',
#  'fleistwirtschaft',
#  'eventuelll',
#  'code',
#  'zuruckzusetzt',
#  'falls',
#  'testbuch',
#  'ausbildungszent',
#  'waage+dosiergerat',
#  'vermalen',
#  'alle',
#  'metallarbeit',
#  'freigeschalten',
#  'augustich',
#  'gruess',
#  'fasnacht',
#  'swissmem-cloud',
#  'automatist',
#  'vollzug',
#  'abklopf',
#  'gutenbergstrass',
#  'imemr',
#  'krummenach',
#  'e-lermittel',
#  'vsw/agvs',
#  'agvs-',
#  'uberschrit',
#  'spiez',
#  'landschaftsgartnerin',
#  'maschine',
#  'auflosen',
#  'merm',
#  'wochend',
#  'd.',
#  'steinman',
#  'hinterst',
#  '’',
#  'ivana',
#  'kaputttel',
#  'zuruckgestzt',
#  'zanolari',
#  'geisst',
#  'instaliert…',
#  'stimmt…',
#  'zugeschicakt',
#  'seriennuimm',
#  'hanspet',
#  'eigend',
#  'einggezahlt',
#  'gerateinstallation',
#  'urs.ruf',
#  'reaaktivi',
#  'anklicakt',
#  'ubernom',
#  'funaktionert',
#  'kontaaktiert',
#  'solotfurn',
#  'gerogerateanzahl',
#  'dhk',
#  'aufseufz',
#  'beziehungsweiseeichn',
#  'struaktur',
#  'freistalt',
#  'fachunterlag',
#  'lamanna',
#  'zweitgerat',
#  'lehrgangsunterlag',
#  'geragerateanzahl',
#  'aaktivierungscod',
#  'sunn.security.provider.certpath.suncertpathbuilderexception',
#  'floriana',
#  'germann',
#  'zuruckknopf',
#  'repetieren',
#  'irèn',
#  'technist',
#  'bwz',
#  'installieren',
#  'wilerweg',
#  'ubernehem',
#  'norme-auuszug',
#  'nocht',
#  'allt',
#  'macbook…',
#  'funaktioniert',
#  'netzwerkfehl',
#  '___________________',
#  'berufsbildn',
#  'seetalstrass',
#  'berufslehre',
#  'irgend',
#  'sturtz',
#  'kuimm',
#  'inkscape',
#  'passwortzurucksetz',
#  'beed',
#  'efz',
#  'seaktion',
#  'e-mail-addresse',
#  'amrhein',
#  'wuthrich',
#  'firmawied',
#  'ziffur',
#  'zusammenschiess',
#  'pkix',
#  'henguely',
#  'zulad',
#  'zuruksetz',
#  'plaku',
#  'geschichte',
#  'teilen-funaktion',
#  'entfurnt',
#  'schulkollegin',
#  'freizuschnall',
#  'vorbereitungsklasse',
#  'schnelllstmog',
#  'eleaktro',
#  'punakt',
#  'baukonstruaktion',
#  'santlich',
#  'rep.',
#  'respeaktiv',
#  'hintufug',
#  'jovanovic',
#  'freundlichr',
#  'leistungsberechnung',
#  'korreakt',
#  'swissmem-seit',
#  'spechtr',
#  'geschaftsaccount-',
#  'europa-fachbuch',
#  'mochtr',
#  'schlepp',
#  'leidlich',
#  'wisteinstell',
#  'bilddatein',
#  'moglichdass',
#  'internetverbindung',
#  'serviceik',
#  'schnelll',
#  'direakt',
#  'j.',
#  'jannuzzi',
#  'dittli',
#  'retia',
#  'zuckerain',
#  'fehlerkorreaktur',
#  'kiefur',
#  'st.',
#  'backerei-bad',
#  'aussschliess',
#  'zwist',
#  'ofnet',
#  'kaputtelwechsel',
#  'aaktion',
#  'rahel',
#  'ausfuhl',
#  '__________________________________________________________________________________________________________________________________',
#  'kaputtt',
#  'freigeschaltenet',
#  'eingeschicakt',
#  'addresse',
#  'mot',
#  'entfurn',
#  'zweiradberuf',
#  'esma',
#  'langwil',
#  'inderkum',
#  'gefugt']
