# %% [markdown]
# # First Extraction

# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('../01_data/chatbot_extract-1.csv', sep=',')
df
# Out:
#     Ticket Number                       ticket    Customer  count of replies  \
# 0    2.019020e+15            Fehler in der App    Swissmem                 1
# 1    2.019020e+15            Fehler in der App        SVBA                 1
# 2    2.019020e+15            Fehler in der App         hep                 1
# 3    2.019020e+15      Anmeldung / Aktivierung        AGVS                 1
# 4    2.019020e+15      Anmeldung / Aktivierung        SVBA                 1
# 5    2.019020e+15   Geräteanzahl überschritten        DIHK                 1
# 6    2.019020e+15            Fehler in der App         BWZ                 1
# 7    2.019020e+15   Geräteanzahl überschritten     VELEDES                 1
# 8    2.019020e+15            Fehler in der App         hep                 1
# 9    2.019020e+15   Geräteanzahl überschritten        DIHK                 1
# 10   2.019020e+15   Geräteanzahl überschritten       BEOOK                 1
# 11   2.019020e+15   Geräteanzahl überschritten        SVBA                 1
# 12   2.019020e+15      Anmeldung / Aktivierung       RICHM                 1
# 13   2.019020e+15   Geräteanzahl überschritten        DIHK                 1
# 14   2.019020e+15            Fehler in der App         hep                 1
# 15   2.019020e+15  Enregistrement / Activation       RICHM                 1
# 16   2.019020e+15      Anmeldung / Aktivierung         BWZ                 1
# 17   2.019020e+15      Anmeldung / Aktivierung         BWZ                 1
# 18   2.019020e+15   Geräteanzahl überschritten        SVBA                 1
# 19   2.019020e+15      Anmeldung / Aktivierung         BWZ                 1
# 20   2.019020e+15            Fehler in der App        SVBA                 1
# 21   2.019020e+15            Fehler in der App        SVBA                 1
# 22   2.019020e+15      Anmeldung / Aktivierung        DIHK                 1
# 23   2.019020e+15      Anmeldung / Aktivierung        DIHK                 1
# 24   2.019020e+15            Fehler in der App        SVBA                 1
# 25   2.019020e+15      Anmeldung / Aktivierung   VELEDESLK                 1
# 26   2.019020e+15            Fehler in der App    DIGINALE                 1
# 27   2.019020e+15      Anmeldung / Aktivierung         hep                 1
# 28   2.019020e+15   Geräteanzahl überschritten       BEOOK                 1
# 29   2.019020e+15      Anmeldung / Aktivierung       RICHM                 1
# ..            ...                          ...         ...               ...
# 51   2.019020e+15          Inhaltlicher Fehler         hep                 1
# 52   2.019020e+15            Fehler in der App        SVBA                 1
# 53   2.019020e+15            Fehler in der App       BEOOK                 1
# 54   2.019020e+15   Geräteanzahl überschritten         SFF                 1
# 55   2.019020e+15   Geräteanzahl überschritten       BEOOK                 1
# 56   2.019020e+15          Inhaltlicher Fehler   COMPENDIO                 1
# 57   2.019020e+15          Inhaltlicher Fehler        SVBA                 1
# 58   2.019020e+15          Inhaltlicher Fehler        SVBA                 1
# 59   2.019020e+15          Inhaltlicher Fehler        SVBA                 1
# 60   2.019020e+15          Inhaltlicher Fehler        SVBA                 1
# 61   2.019020e+15          Inhaltlicher Fehler       BEOOK                 1
# 62   2.019020e+15          Inhaltlicher Fehler        SVBA                 1
# 63   2.019020e+15   Geräteanzahl überschritten       BEOOK                 1
# 64   2.017100e+15   Geräteanzahl überschritten    VSRT-BBZ                 1
# 65   2.017100e+15      Anmeldung / Aktivierung      SMS-SG                 1
# 66   2.017100e+15          Inhaltlicher Fehler         hep                 1
# 67   2.017100e+15      Anmeldung / Aktivierung       BEOOK                 1
# 68   2.017100e+15   Geräteanzahl überschritten        SVBA                 1
# 69   2.017100e+15            Fehler in der App     VELEDES                 1
# 70   2.017100e+15            Fehler in der App        SVBA                 1
# 71   2.017100e+15            Fehler in der App         hep                 1
# 72   2.017100e+15          Inhaltlicher Fehler       RICHM                 1
# 73   2.016080e+15           Login / Activation  BEOOK_TEST                 1
# 74   2.015070e+15          Inhaltlicher Fehler       BEOOK                 1
# 75   2.016090e+15           Login / Activation       BEOOK                 1
# 76   2.016090e+15          Inhaltlicher Fehler         hep                 1
# 77   2.016090e+15          Inhaltlicher Fehler         hep                 1
# 78   2.016090e+15          Inhaltlicher Fehler         hep                 1
# 79   2.016090e+15          Inhaltlicher Fehler         hep                 1
# 80   2.016090e+15          Inhaltlicher Fehler         hep                 1
#
#                                              ticket.1  \
# 0   Normenauszug 2018, Rechenbuch Metall, Tabellen...
# 1    Ich kann die Bilder nicht mehr öffnen um mit ...
# 2   Leider fehlen mir paar Kapitel im Lehrmittel (...
# 3   Ich kann im FK z.b. die Seite 605 nicht lesen ...
# 4   Ich kann das Kapitel Technisches Englisch nich...
# 5                    Bitte iphone und ipad entfernen.
# 6    Mein problem ist, dass ich selbst wenn ich mi...
# 7   Nun konnte ich das Buch Spezielle Branchenkund...
# 8   Ich kann in der Klasse F(18)-KSS den Bildschir...
# 9   Ich würde gerne die Lizenzen bei dem Geräten S...
# 10  Bitte das ipad aktiviert lassen und die andere...
# 11  In meinem Beook funktionieren die Inhalte des ...
# 12  Ich wollte heute das beook auf meinem Laptop a...
# 13  hab mir einen neuen Laptop gekauft und da steh...
# 14  ,leider kann ich die integrierten Videos der A...
# 15  beook Konto abgemeldetneu restent mit 2 voir @...
# 16   Ich kann in meinem beook keine Lehrmittel ehr...
# 17  Guten Tag,Bei mir funktioniert das Beook tipto...
# 18  Geräteanzahl wurde überrschritten, ohne dass e...
# 19  Guten Tag Bei mir Funktioniert das Beook auch ...
# 20  Ich habe einen Anzeige Fehler bei mehreren Büc...
# 21  Bei mir funktioniert die App nicht richtig da ...
# 22  Wie kann ich mein Passwort zuücksetzen, da ich...
# 23  Ich werde  ein der IHK Hannover meinen Technis...
# 24  Zeichnungen werden vom Inkscape manchmal nicht...
# 25  Wenn ich mich anmelde und den Aktivierungscode...
# 26                   Besprochen mit Christian Heimann
# 27  Das Problem können wir nicht beheben, da die e...
# 28  Offenbar habe ich die Geräteanzahl überschritt...
# 29   hat das Kundenkonto erstellt.Das Ebookwurde f...
# ..                                                ...
# 51  Ich kann die alles klar Fragen meines Detailha...
# 52  Wenn in der App, z.B. nur Pflichtaufgaben anek...
# 53  Bei jedem ersten Start von Beook (Heute 14:30)...
# 54                        Entfernen der App vom I-Pad
# 55                                              I-pad
# 56  Der folgende Link im Buch "Projektmanagement -...
# 57  Formelsammlungkein geordnetes inhaltsverzeichn...
# 58  das inhaltsverzeichniss ist viel zu undefinier...
# 59  Formel Buch ist ein einziges Chaso.Kein sauber...
# 60  Das Inhaltsverzeichniss ist zu wenig Detailier...
# 61  Das Formelbuch "Formelsammlung Autoberufe" ist...
# 62  Das Inhaltverzeichnis im Formelbuch ist schlec...
# 63  Da ich mir neulich einen neuen Laptop zulegen ...
# 64  ich habe die maximalen anzahlen von meinen büc...
# 65  Hatte mein ipad bei der Reparatur und kann mic...
# 66  Gesellschaft B.Bei den Verstanden Fragen komme...
# 67                                                NaN
# 68  bei mir steht gerätenanzahl überschriten obwoh...
# 69  die grösse der buchstaben lässt sich nicht ver...
# 70  Ich komme nicht auf das Bild und kann nichts A...
# 71  Ich kann Gesellschaft, Ausgabe B nicht mehr he...
# 72  Eigentlich habe ich keinen inhaltlichen Fehler...
# 73       Integration liefert kein cloudencryption key
# 74                      Ich kann nur 10 seiten nutzen
# 75            Kann nicht registrieren mint neuem user
# 76                       Meine Coupon Code geht nich
# 77                       meine coupon-code geht nicht
# 78  Im Lehrmittel "Deutsch im ABU", 3. Auflage gib...
# 79  Nach Einlösen des Coupons (d7a3f42b2c7b) ersch...
# 80  Ich musste mir für den Allgemeinbildungs Unter...
#
#                 ticket_state                                  ticket_template
# 0          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 1          closed successful        Coupon einlösen, Produkte nicht vorhanden
# 2          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 3          closed successful                                            Linux
# 4          closed successful        Coupon einlösen, Produkte nicht vorhanden
# 5          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 6         closed_max_devices                                            Linux
# 7   closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 8          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 9          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 10         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 11         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 12  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 13         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 14         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 15                       new      Mac: Access Denied -> Cookies, Virenscanner
# 16         closed successful                                            Linux
# 17         closed successful                                            Linux
# 18         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 19                      open                                            Linux
# 20         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 21         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 22         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 23                       new                                            Linux
# 24         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 25                      open        Coupon einlösen, Produkte nicht vorhanden
# 26    closed_old_app_version                                            Linux
# 27  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 28         closed successful             Anmeldung - Hinweise für Aktivierung
# 29  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# ..                       ...                                              ...
# 51         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 52         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 53  closed_waiting_for_reply             Anmeldung - Hinweise für Aktivierung
# 54  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 55         closed successful             Anmeldung - Hinweise für Aktivierung
# 56         closed successful                           Abmelden, neu anmelden
# 57         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 58         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 59         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 60         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 61         closed successful             Anmeldung - Hinweise für Aktivierung
# 62         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 63         closed successful             Anmeldung - Hinweise für Aktivierung
# 64        closed_max_devices  Floating Lizenz, Geräte entfernt, Konfiguration
# 65        closed_max_devices        Coupon einlösen, Produkte nicht vorhanden
# 66         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 67         closed_app_misuse             Anmeldung - Hinweise für Aktivierung
# 68        closed_max_devices        Coupon einlösen, Produkte nicht vorhanden
# 69  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 70  closed_waiting_for_reply        Coupon einlösen, Produkte nicht vorhanden
# 71         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 72         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 73         closed successful             Anmeldung - Hinweise für Aktivierung
# 74         closed successful             Anmeldung - Hinweise für Aktivierung
# 75         closed successful             Anmeldung - Hinweise für Aktivierung
# 76         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 77         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 78         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 79         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 80         closed successful      Mac: Access Denied -> Cookies, Virenscanner
#
# [81 rows x 7 columns]

# %%
# some informations
print('shape of dataframe',df.shape)
print('any duplicates?',df.duplicated().any())
print('any null values?')
df.isna().any()
# Out:
# shape of dataframe (81, 7)
# any duplicates? True
# any null values?
# Ticket Number       False
# ticket              False
# Customer            False
# count of replies    False
# ticket.1             True
# ticket_state        False
# ticket_template     False
# dtype: bool

# %%
df.describe() # Only 1 as 'count of replies' value
# Out:
#        count of replies
# count              81.0
# mean                1.0
# std                 0.0
# min                 1.0
# 25%                 1.0
# 50%                 1.0
# 75%                 1.0
# max                 1.0

# %% [markdown]
# Show duplicates

# %%
df[df.duplicated(keep=False)]
# Out:
#     Ticket Number                      ticket   Customer  count of replies  \
# 32   2.019020e+15         Inhaltlicher Fehler        hep                 1
# 36   2.019020e+15           Fehler in der App       SVBA                 1
# 38   2.019020e+15  Geräteanzahl überschritten        SFF                 1
# 39   2.019020e+15  Geräteanzahl überschritten      BEOOK                 1
# 40   2.019020e+15         Inhaltlicher Fehler  COMPENDIO                 1
# 41   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 42   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 43   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 44   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 45   2.019020e+15         Inhaltlicher Fehler      BEOOK                 1
# 51   2.019020e+15         Inhaltlicher Fehler        hep                 1
# 52   2.019020e+15           Fehler in der App       SVBA                 1
# 54   2.019020e+15  Geräteanzahl überschritten        SFF                 1
# 55   2.019020e+15  Geräteanzahl überschritten      BEOOK                 1
# 56   2.019020e+15         Inhaltlicher Fehler  COMPENDIO                 1
# 57   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 58   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 59   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 60   2.019020e+15         Inhaltlicher Fehler       SVBA                 1
# 61   2.019020e+15         Inhaltlicher Fehler      BEOOK                 1
#
#                                              ticket.1  \
# 32  Ich kann die alles klar Fragen meines Detailha...
# 36  Wenn in der App, z.B. nur Pflichtaufgaben anek...
# 38                        Entfernen der App vom I-Pad
# 39                                              I-pad
# 40  Der folgende Link im Buch "Projektmanagement -...
# 41  Formelsammlungkein geordnetes inhaltsverzeichn...
# 42  das inhaltsverzeichniss ist viel zu undefinier...
# 43  Formel Buch ist ein einziges Chaso.Kein sauber...
# 44  Das Inhaltsverzeichniss ist zu wenig Detailier...
# 45  Das Formelbuch "Formelsammlung Autoberufe" ist...
# 51  Ich kann die alles klar Fragen meines Detailha...
# 52  Wenn in der App, z.B. nur Pflichtaufgaben anek...
# 54                        Entfernen der App vom I-Pad
# 55                                              I-pad
# 56  Der folgende Link im Buch "Projektmanagement -...
# 57  Formelsammlungkein geordnetes inhaltsverzeichn...
# 58  das inhaltsverzeichniss ist viel zu undefinier...
# 59  Formel Buch ist ein einziges Chaso.Kein sauber...
# 60  Das Inhaltsverzeichniss ist zu wenig Detailier...
# 61  Das Formelbuch "Formelsammlung Autoberufe" ist...
#
#                 ticket_state                              ticket_template
# 32         closed successful  Mac: Access Denied -> Cookies, Virenscanner
# 36         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 38  closed_waiting_for_reply  Mac: Access Denied -> Cookies, Virenscanner
# 39         closed successful         Anmeldung - Hinweise für Aktivierung
# 40         closed successful                       Abmelden, neu anmelden
# 41         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 42         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 43         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 44         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 45         closed successful         Anmeldung - Hinweise für Aktivierung
# 51         closed successful  Mac: Access Denied -> Cookies, Virenscanner
# 52         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 54  closed_waiting_for_reply  Mac: Access Denied -> Cookies, Virenscanner
# 55         closed successful         Anmeldung - Hinweise für Aktivierung
# 56         closed successful                       Abmelden, neu anmelden
# 57         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 58         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 59         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 60         closed successful    Coupon einlösen, Produkte nicht vorhanden
# 61         closed successful         Anmeldung - Hinweise für Aktivierung

# %% [markdown]
# ## Modify extraction

# %%
    df.drop('Ticket Number', axis='columns', inplace=True)
df.drop('count of replies', axis='columns', inplace=True)

# %%
df
# Out:
#                          ticket    Customer  count of replies  \
# 0             Fehler in der App    Swissmem                 1
# 1             Fehler in der App        SVBA                 1
# 2             Fehler in der App         hep                 1
# 3       Anmeldung / Aktivierung        AGVS                 1
# 4       Anmeldung / Aktivierung        SVBA                 1
# 5    Geräteanzahl überschritten        DIHK                 1
# 6             Fehler in der App         BWZ                 1
# 7    Geräteanzahl überschritten     VELEDES                 1
# 8             Fehler in der App         hep                 1
# 9    Geräteanzahl überschritten        DIHK                 1
# 10   Geräteanzahl überschritten       BEOOK                 1
# 11   Geräteanzahl überschritten        SVBA                 1
# 12      Anmeldung / Aktivierung       RICHM                 1
# 13   Geräteanzahl überschritten        DIHK                 1
# 14            Fehler in der App         hep                 1
# 15  Enregistrement / Activation       RICHM                 1
# 16      Anmeldung / Aktivierung         BWZ                 1
# 17      Anmeldung / Aktivierung         BWZ                 1
# 18   Geräteanzahl überschritten        SVBA                 1
# 19      Anmeldung / Aktivierung         BWZ                 1
# 20            Fehler in der App        SVBA                 1
# 21            Fehler in der App        SVBA                 1
# 22      Anmeldung / Aktivierung        DIHK                 1
# 23      Anmeldung / Aktivierung        DIHK                 1
# 24            Fehler in der App        SVBA                 1
# 25      Anmeldung / Aktivierung   VELEDESLK                 1
# 26            Fehler in der App    DIGINALE                 1
# 27      Anmeldung / Aktivierung         hep                 1
# 28   Geräteanzahl überschritten       BEOOK                 1
# 29      Anmeldung / Aktivierung       RICHM                 1
# ..                          ...         ...               ...
# 51          Inhaltlicher Fehler         hep                 1
# 52            Fehler in der App        SVBA                 1
# 53            Fehler in der App       BEOOK                 1
# 54   Geräteanzahl überschritten         SFF                 1
# 55   Geräteanzahl überschritten       BEOOK                 1
# 56          Inhaltlicher Fehler   COMPENDIO                 1
# 57          Inhaltlicher Fehler        SVBA                 1
# 58          Inhaltlicher Fehler        SVBA                 1
# 59          Inhaltlicher Fehler        SVBA                 1
# 60          Inhaltlicher Fehler        SVBA                 1
# 61          Inhaltlicher Fehler       BEOOK                 1
# 62          Inhaltlicher Fehler        SVBA                 1
# 63   Geräteanzahl überschritten       BEOOK                 1
# 64   Geräteanzahl überschritten    VSRT-BBZ                 1
# 65      Anmeldung / Aktivierung      SMS-SG                 1
# 66          Inhaltlicher Fehler         hep                 1
# 67      Anmeldung / Aktivierung       BEOOK                 1
# 68   Geräteanzahl überschritten        SVBA                 1
# 69            Fehler in der App     VELEDES                 1
# 70            Fehler in der App        SVBA                 1
# 71            Fehler in der App         hep                 1
# 72          Inhaltlicher Fehler       RICHM                 1
# 73           Login / Activation  BEOOK_TEST                 1
# 74          Inhaltlicher Fehler       BEOOK                 1
# 75           Login / Activation       BEOOK                 1
# 76          Inhaltlicher Fehler         hep                 1
# 77          Inhaltlicher Fehler         hep                 1
# 78          Inhaltlicher Fehler         hep                 1
# 79          Inhaltlicher Fehler         hep                 1
# 80          Inhaltlicher Fehler         hep                 1
#
#                                              ticket.1  \
# 0   Normenauszug 2018, Rechenbuch Metall, Tabellen...
# 1    Ich kann die Bilder nicht mehr öffnen um mit ...
# 2   Leider fehlen mir paar Kapitel im Lehrmittel (...
# 3   Ich kann im FK z.b. die Seite 605 nicht lesen ...
# 4   Ich kann das Kapitel Technisches Englisch nich...
# 5                    Bitte iphone und ipad entfernen.
# 6    Mein problem ist, dass ich selbst wenn ich mi...
# 7   Nun konnte ich das Buch Spezielle Branchenkund...
# 8   Ich kann in der Klasse F(18)-KSS den Bildschir...
# 9   Ich würde gerne die Lizenzen bei dem Geräten S...
# 10  Bitte das ipad aktiviert lassen und die andere...
# 11  In meinem Beook funktionieren die Inhalte des ...
# 12  Ich wollte heute das beook auf meinem Laptop a...
# 13  hab mir einen neuen Laptop gekauft und da steh...
# 14  ,leider kann ich die integrierten Videos der A...
# 15  beook Konto abgemeldetneu restent mit 2 voir @...
# 16   Ich kann in meinem beook keine Lehrmittel ehr...
# 17  Guten Tag,Bei mir funktioniert das Beook tipto...
# 18  Geräteanzahl wurde überrschritten, ohne dass e...
# 19  Guten Tag Bei mir Funktioniert das Beook auch ...
# 20  Ich habe einen Anzeige Fehler bei mehreren Büc...
# 21  Bei mir funktioniert die App nicht richtig da ...
# 22  Wie kann ich mein Passwort zuücksetzen, da ich...
# 23  Ich werde  ein der IHK Hannover meinen Technis...
# 24  Zeichnungen werden vom Inkscape manchmal nicht...
# 25  Wenn ich mich anmelde und den Aktivierungscode...
# 26                   Besprochen mit Christian Heimann
# 27  Das Problem können wir nicht beheben, da die e...
# 28  Offenbar habe ich die Geräteanzahl überschritt...
# 29   hat das Kundenkonto erstellt.Das Ebookwurde f...
# ..                                                ...
# 51  Ich kann die alles klar Fragen meines Detailha...
# 52  Wenn in der App, z.B. nur Pflichtaufgaben anek...
# 53  Bei jedem ersten Start von Beook (Heute 14:30)...
# 54                        Entfernen der App vom I-Pad
# 55                                              I-pad
# 56  Der folgende Link im Buch "Projektmanagement -...
# 57  Formelsammlungkein geordnetes inhaltsverzeichn...
# 58  das inhaltsverzeichniss ist viel zu undefinier...
# 59  Formel Buch ist ein einziges Chaso.Kein sauber...
# 60  Das Inhaltsverzeichniss ist zu wenig Detailier...
# 61  Das Formelbuch "Formelsammlung Autoberufe" ist...
# 62  Das Inhaltverzeichnis im Formelbuch ist schlec...
# 63  Da ich mir neulich einen neuen Laptop zulegen ...
# 64  ich habe die maximalen anzahlen von meinen büc...
# 65  Hatte mein ipad bei der Reparatur und kann mic...
# 66  Gesellschaft B.Bei den Verstanden Fragen komme...
# 67                                                NaN
# 68  bei mir steht gerätenanzahl überschriten obwoh...
# 69  die grösse der buchstaben lässt sich nicht ver...
# 70  Ich komme nicht auf das Bild und kann nichts A...
# 71  Ich kann Gesellschaft, Ausgabe B nicht mehr he...
# 72  Eigentlich habe ich keinen inhaltlichen Fehler...
# 73       Integration liefert kein cloudencryption key
# 74                      Ich kann nur 10 seiten nutzen
# 75            Kann nicht registrieren mint neuem user
# 76                       Meine Coupon Code geht nich
# 77                       meine coupon-code geht nicht
# 78  Im Lehrmittel "Deutsch im ABU", 3. Auflage gib...
# 79  Nach Einlösen des Coupons (d7a3f42b2c7b) ersch...
# 80  Ich musste mir für den Allgemeinbildungs Unter...
#
#                 ticket_state                                  ticket_template
# 0          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 1          closed successful        Coupon einlösen, Produkte nicht vorhanden
# 2          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 3          closed successful                                            Linux
# 4          closed successful        Coupon einlösen, Produkte nicht vorhanden
# 5          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 6         closed_max_devices                                            Linux
# 7   closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 8          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 9          closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 10         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 11         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 12  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 13         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 14         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 15                       new      Mac: Access Denied -> Cookies, Virenscanner
# 16         closed successful                                            Linux
# 17         closed successful                                            Linux
# 18         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 19                      open                                            Linux
# 20         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 21         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 22         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 23                       new                                            Linux
# 24         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 25                      open        Coupon einlösen, Produkte nicht vorhanden
# 26    closed_old_app_version                                            Linux
# 27  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 28         closed successful             Anmeldung - Hinweise für Aktivierung
# 29  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# ..                       ...                                              ...
# 51         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 52         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 53  closed_waiting_for_reply             Anmeldung - Hinweise für Aktivierung
# 54  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 55         closed successful             Anmeldung - Hinweise für Aktivierung
# 56         closed successful                           Abmelden, neu anmelden
# 57         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 58         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 59         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 60         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 61         closed successful             Anmeldung - Hinweise für Aktivierung
# 62         closed successful        Coupon einlösen, Produkte nicht vorhanden
# 63         closed successful             Anmeldung - Hinweise für Aktivierung
# 64        closed_max_devices  Floating Lizenz, Geräte entfernt, Konfiguration
# 65        closed_max_devices        Coupon einlösen, Produkte nicht vorhanden
# 66         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 67         closed_app_misuse             Anmeldung - Hinweise für Aktivierung
# 68        closed_max_devices        Coupon einlösen, Produkte nicht vorhanden
# 69  closed_waiting_for_reply      Mac: Access Denied -> Cookies, Virenscanner
# 70  closed_waiting_for_reply        Coupon einlösen, Produkte nicht vorhanden
# 71         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 72         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 73         closed successful             Anmeldung - Hinweise für Aktivierung
# 74         closed successful             Anmeldung - Hinweise für Aktivierung
# 75         closed successful             Anmeldung - Hinweise für Aktivierung
# 76         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 77         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 78         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 79         closed successful      Mac: Access Denied -> Cookies, Virenscanner
# 80         closed successful      Mac: Access Denied -> Cookies, Virenscanner
#
# [81 rows x 6 columns]
